# %%
import pprint

import requests

server = "https://rest.ensembl.org"
ext = "/variation/human/rs142572218?pops=1"
headers = {"Content-Type": "application/json", "Accept": "application/json"}
r = requests.get(server + ext, headers=headers)
pprint.pprint(r.json())
# Out:
# {'MAF': 0.000799,
#  'ambiguity': 'H',
#  'clinical_significance': ['not provided', 'pathogenic'],
#  'evidence': ['Frequency',
#               '1000Genomes',
#               'Cited',
#               'ESP',
#               'Phenotype_or_Disease',
#               'ExAC',
#               'TOPMed',
#               'gnomAD'],
#  'mappings': [{'allele_string': 'C/A/T',
#                'ancestral_allele': 'C',
#                'assembly_name': 'GRCh38',
#                'coord_system': 'chromosome',
#                'end': 133454548,
#                'location': '9:133454548-133454548',
#                'seq_region_name': '9',
#                'start': 133454548,
#                'strand': 1},
#               {'allele_string': 'C/A/T',
#                'ancestral_allele': None,
#                'assembly_name': 'GRCh38',
#                'coord_system': 'chromosome',
#                'end': 133454696,
#                'location': 'CHR_HG2030_PATCH:133454696-133454696',
# ...
