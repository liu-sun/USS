# %%
import pprint

import requests

server = "https://rest.ensembl.org"
ext = "/vep/human/hgvs/ADAMTS13:p.R1060W?"
headers = {"Content-Type": "application/json", "Accept": "application/json"}
r = requests.get(server + ext, headers=headers)
pprint.pprint(r.json())
# Out:
# [{'allele_string': 'C/T',
#   'assembly_name': 'GRCh38',
#   'colocated_variants': [{'allele_string': 'HGMD_MUTATION',
#                           'end': 133454548,
#                           'id': 'CM062410',
#                           'phenotype_or_disease': 1,
#                           'seq_region_name': '9',
#                           'start': 133454548,
#                           'strand': 1},
#                          {'allele_string': 'C/A/T',
#                           'clin_sig': ['not_provided', 'pathogenic'],
#                           'clin_sig_allele': 'T:not_provided;T:pathogenic',
#                           'end': 133454548,
#                           'frequencies': {'T': {'aa': 0.0004543,
#                                                 'afr': 0.0008,
#                                                 'amr': 0,
#                                                 'ea': 0.0009302,
#                                                 'eas': 0,
# ...
