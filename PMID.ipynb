# %%
import pprint

import requests

server = "https://rest.ensembl.org"
ext = "/variation/human/pmid/11586351?"
headers = {"Content-Type": "application/json", "Accept": "application/json"}
r = requests.get(server + ext, headers=headers)
pprint.pprint(r.json())
# Out:
# [{'MAF': None,
#   'ambiguity': 'S',
#   'clinical_significance': ['pathogenic'],
#   'evidence': ['Cited', 'Phenotype_or_Disease'],
#   'mappings': [{'allele_string': 'C/G',
#                 'ancestral_allele': 'C',
#                 'assembly_name': 'GRCh38',
#                 'coord_system': 'chromosome',
#                 'end': 133424434,
#                 'location': '9:133424434-133424434',
#                 'seq_region_name': '9',
#                 'start': 133424434,
#                 'strand': 1},
#                {'allele_string': 'C/G',
#                 'ancestral_allele': None,
#                 'assembly_name': 'GRCh38',
#                 'coord_system': 'chromosome',
#                 'end': 133424582,
#                 'location': 'CHR_HG2030_PATCH:133424582-133424582',
#                 'seq_region_name': 'CHR_HG2030_PATCH',
#                 'start': 133424582,
#                 'strand': 1}],
#   'minor_allele': None,
# ...
